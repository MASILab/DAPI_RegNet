# %%
import pandas as pd
# Out:
# /tmp/ipykernel_1304547/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('/fs5/p_masi/rudravg/MxIF_Vxm_Registered_V2/GCA022ACB_TISSUE03/registered_GCA022ACB_T3_instances.csv')

df2 = pd.read_csv('/fs5/p_masi/rudravg/MxIF_Vxm_Registered_V2/GCA022ACB_TISSUE03/unregistered_GCA022ACB_T3_instances.csv')

# %%
df.head()
# Out:
#    Instance   Centroid_X  Centroid_Y  Mean_CD11B  Mean_CD20  Mean_CD3d  \
# 0         1  9432.198864  431.250000    3.454545   0.267045   0.202652
# 1         2  9268.344828  435.200000    1.144828   0.041379   0.101149
# 2         3  8914.631491  435.244556    0.757119   0.000000   0.000000
# 3         4  8940.391429  436.074286    1.914286   0.011429   0.000000
# 4         5  9288.080092  437.276888    2.340961   0.000000   0.018307
#
#    Mean_CD45  Mean_CD4  Mean_CD68  Mean_CD8  Mean_CgA  Mean_Lysozyme  \
# 0   0.018939  0.994318   0.168561  0.196970  2.617424       0.962121
# 1   0.071264  0.043678   0.110345  0.050575  0.029885       0.395402
# 2   2.911223  0.013400  33.936348  0.000000  0.000000       0.914573
# 3   3.111429  0.000000  11.025714  0.000000  0.000000       0.568571
# 4   0.000000  0.000000   0.000000  0.000000  0.004577       0.036613
#
#    Mean_NaKATPase  Mean_PanCK  Mean_SMA  Mean_Sox9  Mean_Vimentin  Mean_OLFM4  \
# ...

# %%
df=df.sort_values('Instance')

# %%
df.head()
# Out:
#     Instance   Centroid_X  Centroid_Y  Mean_CD11B  Mean_CD20  Mean_CD3d  \
# 84         1  9432.198864  431.250000    3.454545   0.267045   0.202652
# 67         2  9268.344828  435.200000    1.144828   0.041379   0.101149
# 87         3  8914.631491  435.244556    0.757119   0.000000   0.000000
# 9          4  8940.391429  436.074286    1.914286   0.011429   0.000000
# 8          5  9288.080092  437.276888    2.340961   0.000000   0.018307
#
#     Mean_CD45  Mean_CD4  Mean_CD68  Mean_CD8  Mean_CgA  Mean_Lysozyme  \
# 84   0.018939  0.994318   0.168561  0.196970  2.617424       0.962121
# 67   0.071264  0.043678   0.110345  0.050575  0.029885       0.395402
# 87   2.911223  0.013400  33.936348  0.000000  0.000000       0.914573
# 9    3.111429  0.000000  11.025714  0.000000  0.000000       0.568571
# 8    0.000000  0.000000   0.000000  0.000000  0.004577       0.036613
#
#     Mean_NaKATPase  Mean_PanCK  Mean_SMA  Mean_Sox9  Mean_Vimentin  Mean_OLFM4
# ...

# %%
df['slide_id'] = 1
df2['slide_id'] = 2

# %%
df2.head()
# Out:
#    Instance   Centroid_X  Centroid_Y  Mean_CD11B  Mean_CD20  Mean_CD3d  \
# 0         1  9432.198864  431.250000    1.009470   0.000000   0.051136
# 1         2  9268.344828  435.200000    2.473563   0.000000   0.002299
# 2         3  8914.631491  435.244556    0.202680   0.000000   0.000000
# 3         4  8940.391429  436.074286    2.322857   0.380000   0.000000
# 4         5  9288.080092  437.276888    4.199085   0.004577   0.022883
#
#    Mean_CD45  Mean_CD4  Mean_CD68  Mean_CD8  Mean_CgA  Mean_Lysozyme  \
# 0   0.024621  1.102273   0.001894  0.068182  2.234848       5.465909
# 1   0.000000  0.000000   0.000000  0.000000  0.000000       0.068966
# 2   1.221106  0.122278  40.961474  0.000000  0.030151       1.348409
# 3   4.137143  0.000000   5.562857  0.000000  0.000000       0.571429
# 4   0.000000  0.000000   0.000000  0.013730  0.000000       0.128146
#
#    Mean_NaKATPase  Mean_PanCK  Mean_SMA  Mean_Sox9  Mean_Vimentin  Mean_OLFM4  \
# ...

# %%
df.head()
# Out:
#     Instance   Centroid_X  Centroid_Y  Mean_CD11B  Mean_CD20  Mean_CD3d  \
# 84         1  9432.198864  431.250000    3.454545   0.267045   0.202652
# 67         2  9268.344828  435.200000    1.144828   0.041379   0.101149
# 87         3  8914.631491  435.244556    0.757119   0.000000   0.000000
# 9          4  8940.391429  436.074286    1.914286   0.011429   0.000000
# 8          5  9288.080092  437.276888    2.340961   0.000000   0.018307
#
#     Mean_CD45  Mean_CD4  Mean_CD68  Mean_CD8  Mean_CgA  Mean_Lysozyme  \
# 84   0.018939  0.994318   0.168561  0.196970  2.617424       0.962121
# 67   0.071264  0.043678   0.110345  0.050575  0.029885       0.395402
# 87   2.911223  0.013400  33.936348  0.000000  0.000000       0.914573
# 9    3.111429  0.000000  11.025714  0.000000  0.000000       0.568571
# 8    0.000000  0.000000   0.000000  0.000000  0.004577       0.036613
#
#     Mean_NaKATPase  Mean_PanCK  Mean_SMA  Mean_Sox9  Mean_Vimentin  \
# ...

# %%
#Save the dataframe
df.to_csv('/fs5/p_masi/rudravg/MxIF_Vxm_Registered_V2/GCA020TIB_TISSUE01/registered_GCA020TIB_instances.csv', index=False)

# %%
df_merged = pd.concat([df, df2], ignore_index=True)

# %%
df_merged.tail()
# Out:
#        Instance   Centroid_X    Centroid_Y  Mean_CD11B  Mean_CD20  Mean_CD3d  \
# 81919     40958  4736.536047  12277.238372    1.108140  15.524419  25.447674
# 81920     40959  4756.905120  12275.168675    1.743976  11.789157  28.120482
# 81921     40960  4712.831014  12281.047714    0.222664   9.679920  25.009940
# 81922     40961  4775.916944  12280.602990    0.277409   4.682724  31.029900
# 81923     40962  4799.280992  12287.900826    1.112948   2.278237  25.699725
#
#        Mean_CD45  Mean_CD4  Mean_CD68  Mean_CD8  Mean_CgA  Mean_Lysozyme  \
# 81919   0.155814  0.000000   0.000000  0.553488  0.800000       0.260465
# 81920   1.018072  0.000000   0.000000  0.364458  0.400602       0.308735
# 81921   0.000000  0.003976   0.000000  0.200795  1.182903       0.115308
# 81922   0.739203  0.000000   0.023256  0.387043  0.348837       0.491694
# 81923   9.911846  0.000000   0.000000  0.223140  0.033058       0.049587
#
# ...

# %%
df_merged.to_csv('/fs5/p_masi/rudravg/MxIF_Vxm_Registered_V2/GCA022ACB_TISSUE03/combined_GCA022ACB_T3_instances.csv', index=False)
