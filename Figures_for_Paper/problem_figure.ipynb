# %%
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import numpy as np

# %%
round0_filepath='/fs5/p_masi/baos1/rudravg/MXIF/MXIF/Helmsley/MxIF/Set06/GCA112TIA/Registered/GCA112TIA_DAPI_DAPI_30ms_ROUND_00.tif'

round_last_filepath='/fs5/p_masi/baos1/rudravg/MXIF/MXIF/Helmsley/MxIF/Set06/GCA112TIA/Registered/GCA112TIA_DAPI_DAPI_12ms_ROUND_19.tif'

mask_path='/fs5/p_masi/baos1/rudravg/MXIF/MXIF/Helmsley/MxIF/Set06/GCA112TIA/Registered/GCA112TIA_RetentionMask.tif'

# %%
round0=np.array(Image.open(round0_filepath))
round_last=np.array(Image.open(round_last_filepath))
mask_path=np.array(Image.open(mask_path))

round0=round0*mask_path
round_last=round_last*mask_path

# %%
plt.imshow(round0)
plt.cmap('gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.imshow(round0)
# ----> 2 plt.cmap('gray')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'cmap'
