# %%
import pandas as pd
# Out:
# /tmp/ipykernel_1659635/2035458946.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('/home/local/VANDERBILT/rudravg/our_data_test.csv')

# %%
df.head()
# Out:
#    nzNorm_Mean_Nuc_ACTG1  nzNorm_Mean_Nuc_ACTININ  nzNorm_Mean_Nuc_BCATENIN  \
# 0               0.000007                 0.000000              0.000000e+00
# 1               0.906276                 0.000097              2.305629e-25
# 2               0.935444                 0.000000              3.845971e-15
# 3               0.000000                 0.000000              0.000000e+00
# 4               0.000000                 0.000000              0.000000e+00
#
#    nzNorm_Mean_Nuc_CD11B  nzNorm_Mean_Nuc_CD20
# 0           1.391748e-20          3.022137e-17
# 1           2.958943e-06          1.233774e-03
# 2           3.010217e-11          8.188239e-12
# 3           0.000000e+00          0.000000e+00
# 4           0.000000e+00          0.000000e+00

# %%
import matplotlib.pyplot as plt

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Flatten the axes array
axes = axes.ravel()

# Create a histogram for each column
for i, column in enumerate(df.columns):
    df[column].hist(ax=axes[i])
    axes[i].set_title(column)

# Remove the extra subplots
for i in range(len(df.columns), len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
